# %%
# !pip install optuna
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

from sklearn import metrics

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from xgboost import XGBRegressor
from catboost import  CatBoostRegressor
from lightgbm import  LGBMRegressor
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_columns', 30)
import optuna
from statsmodels.stats.outliers_influence import variance_inflation_factor
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error
import optuna
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU, Dropout
from tensorflow.keras.callbacks import EarlyStopping
from keras.optimizers import Adam, SGD, RMSprop, Adagrad
from sklearn.preprocessing import MinMaxScaler
# Out:
# Requirement already satisfied: optuna in c:\users\admin\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\admin\anaconda3\lib\site-packages (from optuna) (1.13.3)
# Requirement already satisfied: colorlog in c:\users\admin\anaconda3\lib\site-packages (from optuna) (6.10.1)
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\lib\site-packages (from optuna) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from optuna) (24.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\admin\anaconda3\lib\site-packages (from optuna) (2.0.34)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in c:\users\admin\anaconda3\lib\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\admin\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.2.3)
# Requirement already satisfied: typing-extensions>=4 in c:\users\admin\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (4.15.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\admin\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.0.1)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: MarkupSafe>=0.9.2 in c:\users\admin\anaconda3\lib\site-packages (from Mako->alembic>=1.5.0->optuna) (2.1.3)
# C:\Users\admin\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):

# %%
pip install --upgrade numpy pandas scipy matplotlib scikit-learn tensorflow keras optuna
# Out:
# Requirement already satisfied: numpy in c:\users\admin\anaconda3\lib\site-packages (1.26.4)
# Collecting numpy
#   Using cached numpy-2.4.1-cp312-cp312-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: pandas in c:\users\admin\anaconda3\lib\site-packages (2.3.3)
# Requirement already satisfied: scipy in c:\users\admin\anaconda3\lib\site-packages (1.16.3)
# Requirement already satisfied: matplotlib in c:\users\admin\anaconda3\lib\site-packages (3.10.8)
# Requirement already satisfied: scikit-learn in c:\users\admin\anaconda3\lib\site-packages (1.8.0)
# Requirement already satisfied: tensorflow in c:\users\admin\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: keras in c:\users\admin\anaconda3\lib\site-packages (3.13.0)
# Requirement already satisfied: optuna in c:\users\admin\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf>=5.28.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (6.33.0)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: rich in c:\users\admin\anaconda3\lib\site-packages (from keras) (13.7.1)
# Requirement already satisfied: namex in c:\users\admin\anaconda3\lib\site-packages (from keras) (0.1.0)
# Requirement already satisfied: optree in c:\users\admin\anaconda3\lib\site-packages (from keras) (0.17.0)
# Requirement already satisfied: alembic>=1.5.0 in c:\users\admin\anaconda3\lib\site-packages (from optuna) (1.13.3)
# Requirement already satisfied: colorlog in c:\users\admin\anaconda3\lib\site-packages (from optuna) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.4.2 in c:\users\admin\anaconda3\lib\site-packages (from optuna) (2.0.34)
# Requirement already satisfied: tqdm in c:\users\admin\anaconda3\lib\site-packages (from optuna) (4.66.5)
# Requirement already satisfied: PyYAML in c:\users\admin\anaconda3\lib\site-packages (from optuna) (6.0.1)
# Requirement already satisfied: Mako in c:\users\admin\anaconda3\lib\site-packages (from alembic>=1.5.0->optuna) (1.2.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\admin\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.44.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorflow) (2025.4.26)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\admin\anaconda3\lib\site-packages (from sqlalchemy>=1.4.2->optuna) (3.0.1)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from colorlog->optuna) (0.4.6)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\admin\anaconda3\lib\site-packages (from rich->keras) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\admin\anaconda3\lib\site-packages (from rich->keras) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\admin\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\admin\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
dataset_train = pd.read_csv('OANDA_EURUSD, 60 (1).csv')

dataset_train
# Out:
#                           time     open     high      low    close      Plot  \
# 0    2025-12-09T13:00:00+03:00  1.16524  1.16543  1.16404  1.16447  1.164591
# 1    2025-12-09T14:00:00+03:00  1.16448  1.16478  1.16381  1.16436  1.164525
# 2    2025-12-09T15:00:00+03:00  1.16436  1.16444  1.16343  1.16377  1.164309
# 3    2025-12-09T16:00:00+03:00  1.16378  1.16400  1.16290  1.16346  1.164067
# 4    2025-12-09T17:00:00+03:00  1.16346  1.16388  1.16282  1.16376  1.163979
# ..                         ...      ...      ...      ...      ...       ...
# 295  2025-12-26T20:00:00+03:00  1.17652  1.17705  1.17616  1.17702  1.177459
# 296  2025-12-26T21:00:00+03:00  1.17704  1.17738  1.17690  1.17720  1.177385
# 297  2025-12-26T22:00:00+03:00  1.17719  1.17768  1.17692  1.17768  1.177469
# 298  2025-12-26T23:00:00+03:00  1.17768  1.17818  1.17724  1.17751  1.177481
# 299  2025-12-27T00:00:00+03:00  1.17751  1.17767  1.17658  1.17710  1.177372
#
#        Plot.1    Plot.2  Shapes  Shapes.1  Shapes.2  Shapes.3  Shapes.4  \
# 0    1.164443  1.164588       0         0         0         0         0
# 1    1.164434  1.164566       0         0         0         0         0
# 2    1.164364  1.164539       0         0         0         0         0
# 3    1.164269  1.164516       0         0         0         0         0
# 4    1.164215  1.164487       0         0         0         0         0
# ..        ...       ...     ...       ...       ...       ...       ...
# 295  1.177846  1.178507       0         0         0         0         0
# 296  1.177778  1.178500       0         0         0         0         0
# 297  1.177768  1.178512       0         0         0         0         0
# 298  1.177741  1.178496       0         0         0         0         0
# 299  1.177673  1.178458       0         0         0         0         0
#
#      Shapes.5  Shapes.6  ...  EMA RSI.2      RSI.3       MA.3  Upper Band.3  \
# 0           0         0  ...  51.937631  52.320222  46.089428     62.087829
# 1           0         0  ...  51.076905  48.494729  47.086277     60.930379
# 2           0         0  ...  49.287356  43.918706  47.961439     58.215497
# 3           0         0  ...  46.953464  39.951789  48.065498     57.943168
# 4           0         0  ...  45.316267  40.404676  47.930948     58.143380
# ..        ...       ...  ...        ...        ...        ...           ...
# 295         0         0  ...  44.319071  37.475843  46.860548     60.858126
# 296         0         0  ...  43.807589  42.273142  46.583044     60.712718
# 297         0         0  ...  44.148833  45.172565  46.401309     60.505351
# 298         0         0  ...  44.981799  47.480697  46.208223     60.141098
# 299         0         0  ...  44.428250  42.767604  45.630821     59.122039
#
#      Lower Band.3  EMA RSI.3      RSI.4       MA.4  Upper Band.4  \
# 0       30.091027  51.937631  52.320222  46.089428     62.087829
# 1       33.242175  51.076905  48.494729  47.086277     60.930379
# 2       37.707381  49.287356  43.918706  47.961439     58.215497
# 3       38.187827  46.953464  39.951789  48.065498     57.943168
# 4       37.718516  45.316267  40.404676  47.930948     58.143380
# ..            ...        ...        ...        ...           ...
# 295     32.862970  44.319071  37.475843  46.860548     60.858126
# 296     32.453371  43.807589  42.273142  46.583044     60.712718
# 297     32.297266  44.148833  45.172565  46.401309     60.505351
# 298     32.275348  44.981799  47.480697  46.208223     60.141098
# 299     32.139603  44.428250  42.767604  45.630821     59.122039
#
#      Lower Band.4  EMA RSI.4  Open Interest (Цена откр.)  \
# 0       30.091027  51.937631                         NaN
# 1       33.242175  51.076905                         NaN
# 2       37.707381  49.287356                         NaN
# 3       38.187827  46.953464                         NaN
# 4       37.718516  45.316267                         NaN
# ..            ...        ...                         ...
# 295     32.862970  44.319071                         NaN
# 296     32.453371  43.807589                         NaN
# 297     32.297266  44.148833                         NaN
# 298     32.275348  44.981799                         NaN
# 299     32.139603  44.428250                         NaN
#
#      Open Interest (Макс.  Open Interest (Мин.)  Open Interest (Закрыть)
# 0                     NaN                   NaN                      NaN
# 1                     NaN                   NaN                      NaN
# 2                     NaN                   NaN                      NaN
# 3                     NaN                   NaN                      NaN
# 4                     NaN                   NaN                      NaN
# ..                    ...                   ...                      ...
# 295                   NaN                   NaN                      NaN
# 296                   NaN                   NaN                      NaN
# 297                   NaN                   NaN                      NaN
# 298                   NaN                   NaN                      NaN
# 299                   NaN                   NaN                      NaN
#
# [300 rows x 100 columns]

# %%
dataset_train.describe(include = 'all')
# Out:
#                              time        open        high         low  \
# count                         300  300.000000  300.000000  300.000000
# unique                        300         NaN         NaN         NaN
# top     2025-12-09T13:00:00+03:00         NaN         NaN         NaN
# freq                            1         NaN         NaN         NaN
# mean                          NaN    1.173430    1.173970    1.172915
# std                           NaN    0.004394    0.004407    0.004400
# min                           NaN    1.162370    1.162490    1.161510
# 25%                           NaN    1.171885    1.172262    1.171315
# 50%                           NaN    1.174015    1.174480    1.173615
# 75%                           NaN    1.176392    1.177042    1.175952
# max                           NaN    1.180540    1.180800    1.179820
#
#              close        Plot      Plot.1      Plot.2      Shapes  \
# count   300.000000  300.000000  300.000000  300.000000  300.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      1.173472    1.173366    1.173097    1.172364    0.043333
# std       0.004374    0.004360    0.004346    0.004380    0.203947
# min       1.162380    1.162567    1.162989    1.163656    0.000000
# 25%       1.171875    1.171851    1.171915    1.171013    0.000000
# 50%       1.174040    1.173908    1.173625    1.173400    0.000000
# 75%       1.176430    1.176369    1.175800    1.174885    0.000000
# max       1.180530    1.179696    1.179270    1.178645    1.000000
#
#           Shapes.1    Shapes.2    Shapes.3    Shapes.4    Shapes.5  \
# count   300.000000  300.000000  300.000000  300.000000  300.000000
# unique         NaN         NaN         NaN         NaN         NaN
# top            NaN         NaN         NaN         NaN         NaN
# freq           NaN         NaN         NaN         NaN         NaN
# mean      0.056667    0.006667    0.006667    0.010000    0.006667
# std       0.231591    0.081513    0.081513    0.099665    0.081513
# min       0.000000    0.000000    0.000000    0.000000    0.000000
# 25%       0.000000    0.000000    0.000000    0.000000    0.000000
# 50%       0.000000    0.000000    0.000000    0.000000    0.000000
# 75%       0.000000    0.000000    0.000000    0.000000    0.000000
# max       1.000000    1.000000    1.000000    1.000000    1.000000
#
#           Shapes.6  ...   EMA RSI.2       RSI.3        MA.3  Upper Band.3  \
# count   300.000000  ...  300.000000  300.000000  300.000000    300.000000
# unique         NaN  ...         NaN         NaN         NaN           NaN
# top            NaN  ...         NaN         NaN         NaN           NaN
# freq           NaN  ...         NaN         NaN         NaN           NaN
# mean      0.010000  ...   55.044668   54.970849   55.120310     70.399787
# std       0.099665  ...   12.006382   13.534442   10.764285     12.163214
# min       0.000000  ...   29.396786   21.319693   36.638040     47.848789
# 25%       0.000000  ...   44.879968   44.506321   45.931654     60.230796
# 50%       0.000000  ...   53.612954   54.026330   55.159843     68.745746
# 75%       0.000000  ...   63.822008   64.583738   61.669518     80.978558
# max       1.000000  ...   83.588348   87.176078   77.191505     92.027655
#
#         Lower Band.3   EMA RSI.3       RSI.4        MA.4  Upper Band.4  \
# count     300.000000  300.000000  300.000000  300.000000    300.000000
# unique           NaN         NaN         NaN         NaN           NaN
# top              NaN         NaN         NaN         NaN           NaN
# freq             NaN         NaN         NaN         NaN           NaN
# mean       39.840833   55.044668   54.970849   55.120310     70.399787
# std        11.553561   12.006382   13.534442   10.764285     12.163214
# min        12.517336   29.396786   21.319693   36.638040     47.848789
# 25%        31.723474   44.879968   44.506321   45.931654     60.230796
# 50%        37.596065   53.612954   54.026330   55.159843     68.745746
# 75%        47.806679   63.822008   64.583738   61.669518     80.978558
# max        63.736424   83.588348   87.176078   77.191505     92.027655
#
#         Lower Band.4   EMA RSI.4  Open Interest (Цена откр.)  \
# count     300.000000  300.000000                         0.0
# unique           NaN         NaN                         NaN
# top              NaN         NaN                         NaN
# freq             NaN         NaN                         NaN
# mean       39.840833   55.044668                         NaN
# std        11.553561   12.006382                         NaN
# min        12.517336   29.396786                         NaN
# 25%        31.723474   44.879968                         NaN
# 50%        37.596065   53.612954                         NaN
# 75%        47.806679   63.822008                         NaN
# max        63.736424   83.588348                         NaN
#
#         Open Interest (Макс.  Open Interest (Мин.)  Open Interest (Закрыть)
# count                    0.0                   0.0                      0.0
# unique                   NaN                   NaN                      NaN
# top                      NaN                   NaN                      NaN
# freq                     NaN                   NaN                      NaN
# mean                     NaN                   NaN                      NaN
# std                      NaN                   NaN                      NaN
# min                      NaN                   NaN                      NaN
# 25%                      NaN                   NaN                      NaN
# 50%                      NaN                   NaN                      NaN
# 75%                      NaN                   NaN                      NaN
# max                      NaN                   NaN                      NaN
#
# [11 rows x 100 columns]

# %%
nan_counts = dataset_train.isna().sum()

# Фильтруем те, где пропусков > 100
cols_with_many_nan = nan_counts[nan_counts > 100]

print(cols_with_many_nan)
# Out:
# Open Interest (Цена откр.)    300
# Open Interest (Макс.          300
# Open Interest (Мин.)          300
# Open Interest (Закрыть)       300
# dtype: int64

# %%
cols_to_drop = dataset_train.columns[dataset_train.isna().sum() > 100]

# 2. Удаляем их из датафрейма
dataset_train.drop(columns=cols_to_drop, inplace=True)

# %%
nan_counts = dataset_train.isna().sum()

# Фильтруем те, где пропусков > 100
cols_with_many_nan = nan_counts[nan_counts > 1]

print(cols_with_many_nan)
# Out:
# Series([], dtype: int64)

# %%
pd.set_option('display.max_rows', None)
dataset_train.dtypes
# Out:
# time             object
# open            float64
# high            float64
# low             float64
# close           float64
# Plot            float64
# Plot.1          float64
# Plot.2          float64
# Shapes            int64
# Shapes.1          int64
# Shapes.2          int64
# Shapes.3          int64
# Shapes.4          int64
# Shapes.5          int64
# Shapes.6          int64
# Shapes.7          int64
# Plot.3          float64
# Plot.4          float64
# Plot.5          float64
# Ma yüksek       float64
# Ma düşük        float64
# Ema yüksek      float64
# Ema düşük       float64
# Chars             int64
# Chars.1           int64
# Plot.6          float64
# Plot.7          float64
# Plot.8          float64
# Ma yüksek.1     float64
# Ma düşük.1      float64
# Ema yüksek.1    float64
# Ema düşük.1     float64
# Chars.2           int64
# Chars.3           int64
# Fast EMA        float64
# Slow EMA        float64
# Plot.9          float64
# Plot.10         float64
# Plot.11         float64
# Plot.12         float64
# BB:Upper        float64
# BB:Lower        float64
# BB:Basis        float64
# Plot.13         float64
# Plot.14         float64
# Plot.15         float64
# Ma yüksek.2     float64
# Ma düşük.2      float64
# Ema yüksek.2    float64
# Ema düşük.2     float64
# Chars.4           int64
# Chars.5           int64
# Plot.16         float64
# Plot.17         float64
# Plot.18         float64
# Ma yüksek.3     float64
# Ma düşük.3      float64
# Ema yüksek.3    float64
# Ema düşük.3     float64
# Chars.6           int64
# Chars.7           int64
# Plot.19         float64
# Plot.20         float64
# Plot.21         float64
# Ma yüksek.4     float64
# Ma düşük.4      float64
# Ema yüksek.4    float64
# Ema düşük.4     float64
# Chars.8           int64
# Chars.9           int64
# Volume            int64
# RSI             float64
# MA              float64
# Upper Band      float64
# Lower Band      float64
# EMA RSI         float64
# RSI.1           float64
# MA.1            float64
# Upper Band.1    float64
# Lower Band.1    float64
# EMA RSI.1       float64
# RSI.2           float64
# MA.2            float64
# Upper Band.2    float64
# Lower Band.2    float64
# EMA RSI.2       float64
# RSI.3           float64
# MA.3            float64
# Upper Band.3    float64
# Lower Band.3    float64
# EMA RSI.3       float64
# RSI.4           float64
# MA.4            float64
# Upper Band.4    float64
# Lower Band.4    float64
# EMA RSI.4       float64
# dtype: object

# %%
# Importing the training set
training_set = dataset_train.iloc[:, 1:2].values

# Importing the test set
dataset_test = pd.read_csv('OANDA_EURUSD, 60 (1).csv')
real_stock_price = dataset_test.iloc[:, 1:2].values

# Feature Scaling
sc = MinMaxScaler(feature_range=(0, 1))
training_set_scaled = sc.fit_transform(training_set)

# Creating a data structure with 60 timesteps and 1 output
X_train = []
y_train = []
for i in range(30, 60):
    X_train.append(training_set_scaled[i-30:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)

# Reshaping
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# Preprocessing test data
dataset_total = pd.concat((dataset_train['open'], dataset_test['open']), axis=0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 30:].values
inputs = inputs.reshape(-1, 1)
inputs = sc.transform(inputs)

X_test = []
for i in range(30, 330):
    X_test.append(inputs[i-30:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
def create_model(trial):
    model = Sequential()

    rnn_type = trial.suggest_categorical('rnn_type', ['LSTM', 'GRU']) # LSTM or GRU.
    
    n_layers = trial.suggest_int('n_layers', 1, 16)
    
    for i in range(n_layers): # necessary to pass sequential data to the next LSTM/GRU layer.
        if i < n_layers - 1:
            return_sequences = True
        else:
            return_sequences = False
        
        units = trial.suggest_int(f'units_{i}', 20, 200)
        dropout = trial.suggest_float(f'dropout_{i}', 0.1, 0.5)

        if rnn_type == 'LSTM':
            model.add(LSTM(units=units, return_sequences=return_sequences, 
                           input_shape=(X_train.shape[1], 1)))
        else:
            model.add(GRU(units=units, return_sequences=return_sequences, 
                          input_shape=(X_train.shape[1], 1)))
        
        model.add(Dropout(dropout))

    # Output layer
    model.add(Dense(units=1))

    # Optimizer selection
    optimizer_name = trial.suggest_categorical('optimizer', ['adam', 'sgd', 'rmsprop', 'adagrad'])
    learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)

    if optimizer_name == 'adam':
        optimizer = Adam(learning_rate=learning_rate, clipvalue=1.0)  # Clipping gradients
    elif optimizer_name == 'sgd':
        optimizer = SGD(learning_rate=learning_rate, clipvalue=1.0)
    elif optimizer_name == 'rmsprop':
        optimizer = RMSprop(learning_rate=learning_rate, clipvalue=1.0)
    elif optimizer_name == 'adagrad':
        optimizer = Adagrad(learning_rate=learning_rate, clipvalue=1.0)

    model.compile(optimizer=optimizer, loss='mean_squared_error')

    return model

def objective(trial):
    model = create_model(trial)
    
    early_stopping = EarlyStopping(monitor='loss', patience=3, restore_best_weights=True) # Early stopping
    
    model.fit(X_train, y_train, epochs=20, 
              batch_size=trial.suggest_int('batch_size', 16, 64), 
              verbose=0, callbacks=[early_stopping])
    
    loss = model.evaluate(X_train, y_train, verbose=0)
    return loss

# Optuna study to find the best hyperparameters
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=10)

print(f"Best trial: {study.best_trial.value}")
print(f"Best hyperparameters: {study.best_trial.params}")
# Out:
# [I 2026-01-10 13:55:43,614] A new study created in memory with name: no-name-1d10be4e-ff4f-4114-8be6-74bd31394a88
# C:\Users\admin\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# C:\Users\admin\AppData\Local\Temp\ipykernel_24272\2903663823.py:31: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   learning_rate = trial.suggest_loguniform('learning_rate', 1e-5, 1e-2)
# [I 2026-01-10 13:55:45,656] Trial 0 finished with value: 0.1159587875008583 and parameters: {'rnn_type': 'GRU', 'n_layers': 1, 'units_0': 44, 'dropout_0': 0.10216124731874295, 'optimizer': 'sgd', 'learning_rate': 0.0013757734938965095, 'batch_size': 43}. Best is trial 0 with value: 0.1159587875008583.
# [I 2026-01-10 13:55:48,336] Trial 1 finished with value: 0.165681853890419 and parameters: {'rnn_type': 'GRU', 'n_layers': 1, 'units_0': 144, 'dropout_0': 0.47932199104525897, 'optimizer': 'rmsprop', 'learning_rate': 6.869232114004998e-05, 'batch_size': 45}. Best is trial 0 with value: 0.1159587875008583.
# [I 2026-01-10 13:56:32,201] Trial 2 finished with value: 0.21583078801631927 and parameters: {'rnn_type': 'GRU', 'n_layers': 5, 'units_0': 80, 'dropout_0': 0.4249557153748267, 'units_1': 61, 'dropout_1': 0.4177762800445155, 'units_2': 25, 'dropout_2': 0.3164225577248928, 'units_3': 101, 'dropout_3': 0.4686791387637035, 'units_4': 172, 'dropout_4': 0.34905766638690205, 'optimizer': 'adam', 'learning_rate': 1.8054210589904222e-05, 'batch_size': 16}. Best is trial 0 with value: 0.1159587875008583.
# [I 2026-01-10 13:56:47,572] Trial 3 finished with value: 0.2093246728181839 and parameters: {'rnn_type': 'LSTM', 'n_layers': 8, 'units_0': 97, 'dropout_0': 0.273584628094366, 'units_1': 121, 'dropout_1': 0.14411709309692644, 'units_2': 195, 'dropout_2': 0.24988780791711893, 'units_3': 33, 'dropout_3': 0.19894096668386943, 'units_4': 193, 'dropout_4': 0.23295972828735603, 'units_5': 153, 'dropout_5': 0.28979877093297557, 'units_6': 81, 'dropout_6': 0.470619878332714, 'units_7': 171, 'dropout_7': 0.3420825012993168, 'optimizer': 'adam', 'learning_rate': 1.0827222094953568e-05, 'batch_size': 29}. Best is trial 0 with value: 0.1159587875008583.
# [I 2026-01-10 13:57:02,572] Trial 4 finished with value: 0.21823984384536743 and parameters: {'rnn_type': 'GRU', 'n_layers': 12, 'units_0': 46, 'dropout_0': 0.3526237719320817, 'units_1': 162, 'dropout_1': 0.2445646845652473, 'units_2': 173, 'dropout_2': 0.21752098687028304, 'units_3': 64, 'dropout_3': 0.4687509760012344, 'units_4': 36, 'dropout_4': 0.47187250976575434, 'units_5': 93, 'dropout_5': 0.3304582954749269, 'units_6': 184, 'dropout_6': 0.38180279140049245, 'units_7': 112, 'dropout_7': 0.30592754213196993, 'units_8': 85, 'dropout_8': 0.14722903090933662, 'units_9': 99, 'dropout_9': 0.476078999694337, 'units_10': 171, 'dropout_10': 0.2795584874316581, 'units_11': 34, 'dropout_11': 0.44377750227916846, 'optimizer': 'sgd', 'learning_rate': 7.306388737325012e-05, 'batch_size': 49}. Best is trial 0 with value: 0.1159587875008583.
# [I 2026-01-10 13:57:12,771] Trial 5 finished with value: 0.21419495344161987 and parameters: {'rnn_type': 'GRU', 'n_layers': 7, 'units_0': 45, 'dropout_0': 0.38140869945386724, 'units_1': 149, 'dropout_1': 0.16972182551356302, 'units_2': 49, 'dropout_2': 0.3043952557480729, 'units_3': 151, 'dropout_3': 0.30477487607602055, 'units_4': 129, 'dropout_4': 0.10645536338896965, 'units_5': 105, 'dropout_5': 0.2314500800912227, 'units_6': 22, 'dropout_6': 0.4806773526332908, 'optimizer': 'adagrad', 'learning_rate': 9.02810949256489e-05, 'batch_size': 51}. Best is trial 0 with value: 0.1159587875008583.

# %%
def create_final_model(best_params):
    model = Sequential()

    n_layers = best_params['n_layers']
    rnn_type = best_params['rnn_type'] 

    for i in range(n_layers):
        return_sequences = True if i < n_layers - 1 else False

        units = best_params[f'units_{i}']
        dropout = best_params[f'dropout_{i}']

        if rnn_type == 'LSTM':
            model.add(LSTM(units=units, return_sequences=return_sequences, 
                           input_shape=(X_train.shape[1], 1)))
        else:  # 'GRU'
            model.add(GRU(units=units, return_sequences=return_sequences, 
                          input_shape=(X_train.shape[1], 1)))

        model.add(Dropout(dropout))

    # Output layer
    model.add(Dense(units=1))

    optimizers = {
        'adam': Adam(learning_rate=best_params['learning_rate']),
        'sgd': SGD(learning_rate=best_params['learning_rate']),
        'rmsprop': RMSprop(learning_rate=best_params['learning_rate']),
        'adagrad': Adagrad(learning_rate=best_params['learning_rate'])
    }
    optimizer = optimizers[best_params['optimizer']]

    # Compile model
    model.compile(optimizer=optimizer, loss='mean_squared_error')

    return model

# %%
best_params = study.best_trial.params

best_params
# Out:
# {'rnn_type': 'GRU',
#  'n_layers': 9,
#  'units_0': 83,
#  'dropout_0': 0.4606559643169592,
#  'units_1': 113,
#  'dropout_1': 0.21603150883212088,
#  'units_2': 115,
#  'dropout_2': 0.2799217563150638,
#  'units_3': 131,
#  'dropout_3': 0.40280885290671553,
#  'units_4': 176,
#  'dropout_4': 0.13730035079216135,
#  'units_5': 140,
#  'dropout_5': 0.2824653886622473,
#  'units_6': 86,
#  'dropout_6': 0.1474030370905151,
#  'units_7': 68,
#  'dropout_7': 0.14284387838808135,
#  'units_8': 71,
#  'dropout_8': 0.362416104963879,
#  'optimizer': 'rmsprop',
#  'learning_rate': 0.00014385189069972162,
#  'batch_size': 56}

# %%
# Building and training the final model with the best hyperparameters

final_model = create_final_model(best_params)
final_model.fit(X_train, y_train, validation_data=(X_test, real_stock_price), epochs=10, batch_size=best_params['batch_size'])
# Out:
# Epoch 1/10
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - loss: 0.2544
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 4
#       1 # Building and training the final model with the best hyperparameters
#       3 final_model = create_final_model(best_params)
# ----> 4 final_model.fit(X_train, y_train, validation_data=(X_test, real_stock_price), epochs=10, batch_size=best_params['batch_size'])
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\optree\ops.py:766, in tree_map(func, tree, is_leaf, none_is_leaf, namespace, *rests)
#     764 leaves, treespec = _C.flatten(tree, is_leaf, none_is_leaf, namespace)
#     765 flat_args = [leaves] + [treespec.flatten_up_to(r) for r in rests]
# --> 766 return treespec.unflatten(map(func, *flat_args))
#
# ValueError: Invalid dtype: object

# %%
object_columns = X_train.select_dtypes(include=['object']).columns
print("Колонки с типом object:", object_columns)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 object_columns = X_train.select_dtypes(include=['object']).columns
#       2 print("Колонки с типом object:", object_columns)
#
# AttributeError: 'numpy.ndarray' object has no attribute 'select_dtypes'

# %%
predicted_stock_price = final_model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_оstock_price)
# Out:
# 39/39 ━━━━━━━━━━━━━━━━━━━━ 5s 101ms/step

# %%
# Visualizing the results

plt.plot(real_stock_price, color='red', label='Real Palantir Price')
plt.plot(predicted_stock_price, color='blue', label='Predicted Palantir Price')
plt.title('Palantir Price Prediction')
plt.xlabel('Time')
plt.ylabel('Palantir Price')
plt.legend()
plt.show()

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score


mse = mean_squared_error(real_stock_price, predicted_stock_price)
rmse = np.sqrt(mse)
mae = mean_absolute_error(real_stock_price, predicted_stock_price)
r2 = r2_score(real_stock_price, predicted_stock_price)

# Print the performance metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"Mean Absolute Error (MAE): {mae}")
print(f"R-squared (R2 Score): {r2}")
# Out:
# Mean Squared Error (MSE): 188.52138820647048
# Root Mean Squared Error (RMSE): 13.730309108190918
# Mean Absolute Error (MAE): 10.27852384311946
# R-squared (R2 Score): 0.3149097500368907

# %%
def predict_future_stock_prices(model, last_known_data, num_future_steps):
    predictions = []
    current_input = last_known_data.copy()
    for _ in range(num_future_steps):
        pred = model.predict(current_input[np.newaxis, :, :])
        predictions.append(pred[0, 0])
        current_input = np.append(current_input[1:], pred, axis=0)
    return np.array(predictions)

# Last known data (from the end of your dataset)
last_known_data = inputs[-10:]

# Number of future steps to predict
num_future_steps = 365  # for example, predict the next 30 days

future_predictions = predict_future_stock_prices(final_model, last_known_data, num_future_steps)
future_predictions = sc.inverse_transform(future_predictions.reshape(-1, 1))

# Create future dates (start date excluded from the period count)
future_dates = pd.date_range(start=dataset_test['Date'].iloc[-1], periods=num_future_steps, inclusive='left')

# Create DataFrame for future dates and predictions
future_df = pd.DataFrame(data={'Date': future_dates, 'Predicted Stock Price': future_predictions.flatten()})
future_df
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 69ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 230ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 94ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 106ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 68ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 97ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 80ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
#           Date  Predicted Stock Price
# 0   2025-06-23             144.212753
# 1   2025-06-24             145.108902
# 2   2025-06-25             145.977631
# 3   2025-06-26             147.004593
# 4   2025-06-27             147.716339
# ..         ...                    ...
# 360 2026-06-18             160.276352
# 361 2026-06-19             160.276352
# 362 2026-06-20             160.276352
# 363 2026-06-21             160.276352
# 364 2026-06-22             160.276352
#
# [365 rows x 2 columns]

# %%
dataset_test
# Out:
#             Date   Price    Open    High     Low     Vol. Change %
# 0     12/19/2025  193.38  186.74  195.00  186.73   76.93M    4.14%
# 1     12/18/2025  185.69  181.51  187.33  181.51   40.22M    4.74%
# 2     12/17/2025  177.29  187.71  187.75  176.50   50.42M   -5.57%
# 3     12/16/2025  187.75  181.65  188.50  181.14   42.07M    2.46%
# 4     12/15/2025  183.25  185.08  187.78  180.03   32.80M   -0.17%
# ...          ...     ...     ...     ...     ...      ...      ...
# 1231  01/27/2021   39.00   32.97   45.00   32.25  170.76M   10.26%
# 1232  01/26/2021   35.37   35.14   36.87   34.32   65.87M   -2.37%
# 1233  01/25/2021   36.23   34.46   39.58   29.56  191.35M   11.20%
# 1234  01/22/2021   32.58   25.85   32.65   25.82  156.84M   25.40%
# 1235  01/21/2021   25.98   26.42   26.68   25.30   29.89M   -1.37%
#
# [1236 rows x 7 columns]
